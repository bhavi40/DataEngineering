# %%
from datetime import datetime

today = datetime.now().strftime("%Y-%m-%d")

spark.sql(f"""
    INSERT INTO telecom.bronze.pipeline_run_log
    VALUES ('cdr', '{today}', 0, current_timestamp())
""")
print(f"✓ CDR logged for {today} — is_processed=0")
# Out:
# ✓ CDR logged for 2026-03-20 — is_processed=0
