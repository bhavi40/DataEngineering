# %%
from datetime import datetime
today = datetime.now().strftime("%Y-%m-%d")

spark.sql(f"""
    INSERT INTO telecom.bronze.pipeline_run_log
    VALUES ('events', '{today}', 0, current_timestamp())
""")
print(f"✓ Events logged for {today}")
# Out:
# ✓ Events logged for 2026-03-20
